# %% [markdown]
# <a href="https://colab.research.google.com/github/srihariharan14/PESUIO-Assignments/blob/main/io_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv('/content/drive/MyDrive/IO/io/SwedishMotorInsurance.csv')
x=dataset.iloc[:,:-1].values
y=dataset.iloc[:,-1].values

# %%
print(x)
# Out:
# [[  1.     1.     1.     1.   455.13 108.  ]
#  [  1.     1.     1.     2.    69.17  19.  ]
#  [  1.     1.     1.     3.    72.88  13.  ]
#  ...
#  [  5.     7.     7.     7.     2.83   1.  ]
#  [  5.     7.     7.     8.    13.06   0.  ]
#  [  5.     7.     7.     9.   384.87  16.  ]]

# %%
print(y)
# Out:
# [392491  46221  15694 ...    966      0 112252]

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values=0, strategy='mean')
imputer.fit(x[:, 4:6])
x[:, 4:6] = imputer.transform(x[:, 4:6])

# %%
print(x)
# Out:
# [[  1.           1.           1.           1.         455.13
#   108.        ]
#  [  1.           1.           1.           2.          69.17
#    19.        ]
#  [  1.           1.           1.           3.          72.88
#    13.        ]
#  ...
#  [  5.           7.           7.           7.           2.83
#     1.        ]
#  [  5.           7.           7.           8.          13.06
#    62.97774068]
#  [  5.           7.           7.           9.         384.87
#    16.        ]]

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values=0, strategy='mean')
y=y.reshape(-1,1)
imputer.fit(y)
y = imputer.transform(y)
y = y.flatten()

# %%
print(y)
# Out:
# [392491.          46221.          15694.         ...    966.
#  312070.49582638 112252.        ]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

# %%
print(x_train)
# Out:
# [[  3.           1.           2.           8.          13.03
#    62.97774068]
#  [  3.           1.           5.           1.         480.43
#    41.        ]
#  [  4.           1.           5.           4.          10.91
#     1.        ]
#  ...
#  [  2.           6.           2.           1.         503.2
#    51.        ]
#  [  2.           7.           3.           1.          35.15
#     1.        ]
#  [  4.           6.           2.           9.         468.91
#    34.        ]]

# %%
print(y_train)
# Out:
# [312070.49582638 129476.            993.         ... 272422.
#    2200.         209378.        ]

# %%
print(x_test)
# Out:
# [[5.00000000e+00 5.00000000e+00 1.00000000e+00 1.00000000e+00
#   9.75000000e+00 6.29777407e+01]
#  [2.00000000e+00 1.00000000e+00 3.00000000e+00 5.00000000e+00
#   1.34820000e+02 1.90000000e+01]
#  [3.00000000e+00 7.00000000e+00 7.00000000e+00 1.00000000e+00
#   2.88360000e+02 1.20000000e+01]
#  ...
#  [2.00000000e+00 1.00000000e+00 6.00000000e+00 4.00000000e+00
#   2.10910000e+02 4.00000000e+00]
#  [2.00000000e+00 3.00000000e+00 3.00000000e+00 1.00000000e+00
#   7.24490000e+02 4.90000000e+01]
#  [2.00000000e+00 4.00000000e+00 3.00000000e+00 6.00000000e+00
#   1.08419000e+03 4.60000000e+01]]

# %%
print(y_test)
# Out:
# [3.12070496e+05 1.11059000e+05 4.12060000e+04 9.95013100e+06
#  6.76893000e+05 7.48040000e+04 3.12070496e+05 1.50990000e+04
#  4.49815000e+05 2.89947000e+06 6.48120000e+04 3.12070496e+05
#  5.94900000e+03 6.93900000e+03 3.72470000e+04 1.61455000e+05
#  7.24400000e+03 6.90600000e+03 3.39250000e+04 5.05940000e+05
#  3.12070496e+05 4.90610000e+04 8.68010000e+04 3.60223000e+05
#  2.05900000e+03 1.25890000e+04 6.13410000e+04 7.67560000e+04
#  4.14590000e+04 5.00670000e+04 4.75910000e+04 1.05430000e+04
#  1.42030000e+04 3.12070496e+05 3.15091200e+06 1.87800000e+03
#  4.73800000e+03 9.25720000e+04 4.74950000e+04 5.20377000e+05
#  3.14420000e+04 7.06240000e+04 4.98440000e+04 4.58100000e+03
#  8.25800000e+03 3.76430000e+04 3.12070496e+05 1.82641000e+05
#  1.30260000e+04 1.94340000e+04 4.70051000e+05 2.96108000e+05
#  4.50864000e+05 3.12070496e+05 2.62900000e+03 3.60290000e+04
#  1.19909000e+05 1.04458500e+06 3.95200000e+03 8.39000000e+03
# ...

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
print(x_train)
# Out:
# [[ 0.00407093 -1.5251464  -1.01339425  1.17043771 -0.19804084  0.00879157]
#  [ 0.00407093 -1.5251464   0.49760515 -1.54090245 -0.10610029 -0.10738336]
#  [ 0.71444781 -1.5251464   0.49760515 -0.37889952 -0.19845786 -0.31882445]
#  ...
#  [-0.70630595  1.00998455 -1.01339425 -1.54090245 -0.10162129 -0.05452309]
#  [-0.70630595  1.51701073 -0.50972778 -1.54090245 -0.1936897  -0.31882445]
#  [ 0.71444781  1.00998455 -1.01339425  1.55777202 -0.10836635 -0.14438555]]

# %%
print(x_test)
# Out:
# [[ 1.42482469  0.50295836 -1.51706072 -1.54090245 -0.19868604  0.00879157]
#  [-0.70630595 -1.5251464  -0.50972778  0.00843479 -0.17408398 -0.22367596]
#  [ 0.00407093  1.51701073  1.50493809 -1.54090245 -0.14388168 -0.26067815]
#  ...
#  [-0.70630595 -1.5251464   1.00127162 -0.37889952 -0.15911659 -0.30296637]
#  [-0.70630595 -0.51109402 -0.50972778 -1.54090245 -0.05809214 -0.06509514]
#  [-0.70630595 -0.00406783 -0.50972778  0.3957691   0.01266313 -0.08095322]]

# %%
print(dataset.describe())
# Out:
#         Kilometres         Zone        Bonus         Make        Insured  \
# count  2182.000000  2182.000000  2182.000000  2182.000000    2182.000000
# mean      2.985793     3.970211     4.015124     4.991751    1092.195270
# std       1.410409     1.988858     2.000516     2.586943    5661.156245
# min       1.000000     1.000000     1.000000     1.000000       0.010000
# 25%       2.000000     2.000000     2.000000     3.000000      21.610000
# 50%       3.000000     4.000000     4.000000     5.000000      81.525000
# 75%       4.000000     6.000000     6.000000     7.000000     389.782500
# max       5.000000     7.000000     7.000000     9.000000  127687.270000
#
#             Claims       Payment
# count  2182.000000  2.182000e+03
# mean     51.865720  2.570076e+05
# std     201.710694  1.017283e+06
# min       0.000000  0.000000e+00
# 25%       1.000000  2.988750e+03
# 50%       5.000000  2.740350e+04
# 75%      21.000000  1.119538e+05
# max    3338.000000  1.824503e+07

# %%
dataset.plot(x="Claims",y=["Payment"])
# Out:
# <Axes: xlabel='Claims'>

# %%
dataset.plot(kind='box',subplots=True,figsize=(12,12))
# Out:
# Kilometres       Axes(0.125,0.11;0.0945122x0.77)
# Zone          Axes(0.238415,0.11;0.0945122x0.77)
# Bonus         Axes(0.351829,0.11;0.0945122x0.77)
# Make          Axes(0.465244,0.11;0.0945122x0.77)
# Insured       Axes(0.578659,0.11;0.0945122x0.77)
# Claims        Axes(0.692073,0.11;0.0945122x0.77)
# Payment       Axes(0.805488,0.11;0.0945122x0.77)
# dtype: object

# %%
import matplotlib.pyplot as plt
plt.scatter(dataset['Claims'],dataset['Payment'])

# add labels and title
plt.xlabel('Claims')
plt.ylabel('Payment')
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import matplotlib.pyplot as plt
plt.scatter(dataset['Insured'],dataset['Payment'])

# add labels and title
plt.xlabel('Insured')
plt.ylabel('Payment')
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import seaborn as sns
sns.pairplot(dataset)

# %%
import seaborn as sns
sns.heatmap(dataset.corr())
# Out:
# <Axes: >

# %%
claims=dataset.iloc[:,5:6].values
payment=dataset.iloc[:,-1].values

# %%
print(claims)
# Out:
# [[108]
#  [ 19]
#  [ 13]
#  ...
#  [  1]
#  [  0]
#  [ 16]]

# %%
print(payment)
# Out:
# [392491  46221  15694 ...    966      0 112252]

# %%
from sklearn.linear_model import LinearRegression

# create X and y
feature_cols = ['Insured', 'Claims']
X = dataset[feature_cols]
y = dataset.Payment

# instantiate and fit
lm1 = LinearRegression()
lm1.fit(X, y)

# print the coefficients
print(lm1.intercept_)
print(lm1.coef_)
# Out:
# 3250.7447407314903
# [  28.38806114 4294.77496915]

# %%
list(zip(feature_cols, lm1.coef_))
# Out:
# [('Insured', 28.388061141628686), ('Claims', 4294.774969150964)]

# %%
sns.heatmap(dataset.corr(), annot=True)
# Out:
# <Axes: >

# %%
from sklearn.metrics import r2_score

lm2 = LinearRegression().fit(X[['Insured', 'Claims']], y)
lm2_preds = lm2.predict(X[['Insured', 'Claims']])

print("R^2 score = ", r2_score(y, lm2_preds))
# Out:
# R^2 score =  0.9950960348341996

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

X = dataset[['Insured', 'Claims']]
y = dataset.Payment

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20,random_state = 2)

regressor = LinearRegression()
regressor.fit(X_train, y_train)
regressor_preds = regressor.predict(X_test)

print("Root Mean Squared error :", np.sqrt(mean_squared_error(y_test, regressor_preds)))
print("R^2 score = ", r2_score(y_test, regressor_preds))
# Out:
# Root Mean Squared error : 75180.8009409333
# R^2 score =  0.995114149224164

# %%
print(X_train)
# Out:
#       Insured  Claims
# 1284   105.76       8
# 515    168.09      33
# 365    424.38      12
# 2057    39.76       4
# 1652     9.96       0
# ...       ...     ...
# 1071    52.97       5
# 433    216.41       4
# 674    665.09      29
# 1099    95.19       3
# 1608   235.24      15
#
# [1745 rows x 2 columns]

# %%
print(y_train)
# Out:
# 1284     14449
# 515     150740
# 365      62560
# 2057     15915
# 1652         0
#          ...
# 1071     10472
# 433      65435
# 674     142262
# 1099     36777
# 1608    106855
# Name: Payment, Length: 1745, dtype: int64

# %%
print(regressor_preds)
# Out:
# [4.05595804e+04 5.34677877e+04 4.55782830e+03 8.83856278e+03
#  6.25618994e+04 5.83970453e+04 4.24510247e+03 1.34939918e+04
#  3.05754251e+04 9.08879161e+04 1.00515227e+05 3.87220119e+05
#  1.78591071e+06 2.39191338e+04 4.15690513e+03 3.11513018e+04
#  3.25843643e+04 1.29895953e+04 5.19899031e+05 1.69521276e+04
#  2.07976030e+05 8.66043875e+03 1.92306330e+05 8.50838975e+04
#  4.21282109e+03 1.66336874e+05 4.18560302e+04 3.12605396e+04
#  1.90953805e+04 8.97073334e+04 4.93866172e+05 4.66072519e+03
#  5.29115104e+04 7.40236086e+05 7.92569366e+05 3.33749698e+04
#  5.78135012e+03 2.71195951e+04 4.30185746e+05 8.94376548e+03
#  2.56294568e+05 2.85956034e+04 6.39672922e+04 2.19815520e+05
#  3.93292778e+05 2.31622508e+04 1.94810276e+04 1.29365616e+04
#  3.99314957e+05 6.28942379e+04 4.80599139e+03 2.53937183e+05
#  2.99274984e+04 4.16966343e+04 1.30259118e+04 8.79044762e+04
#  1.34043533e+04 3.03131389e+04 1.07966742e+05 8.32614475e+04
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
y_train_array = y_train.to_numpy()
y_reshape_train = y_train_array.reshape(1, -1)
plt.scatter(X_train.Claims, y_train, color='red')
plt.plot(X_train.Claims, regressor.predict(X_train), color='blue')
plt.title('Claims vs Payment (Training set)')
plt.xlabel('Claims')
plt.ylabel('Payment')
plt.show()

# %%
plt.scatter(X_test.Claims, y_test, color = 'red')
plt.plot(X_test.Claims, regressor.predict(X_test), color = 'blue')
plt.title('claims vs payment (Test set)')
plt.xlabel('claims')
plt.ylabel('payment')
plt.show()

# %%
import numpy as np

def gradient_descent(x,y):
    m_curr = b_curr = 0
    iterations = 10000
    n = len(x)
    learning_rate = 0.08

    for i in range(iterations):
        y_predicted = m_curr * x + b_curr
        cost = (1/n) * sum([val**2 for val in (y-y_predicted)])
        md = -(2/n)*sum(x*(y-y_predicted))
        bd = -(2/n)*sum(y-y_predicted)
        m_curr = m_curr - learning_rate * md
        b_curr = b_curr - learning_rate * bd
        print ("m {}, b {}, cost {} iteration {}".format(m_curr,b_curr,cost, i))

x = np.array([1,2,3,4,5])
y = np.array([5,7,9,11,13])

gradient_descent(x,y)
# Out:
# Streaming output truncated to the last 5000 lines.
# m 2.000000000000001, b 2.9999999999999947, cost 1.0255191767873153e-29 iteration 5000
# m 2.000000000000002, b 2.999999999999995, cost 1.0255191767873153e-29 iteration 5001
# m 2.000000000000001, b 2.9999999999999947, cost 1.0255191767873153e-29 iteration 5002
# m 2.000000000000002, b 2.999999999999995, cost 1.0255191767873153e-29 iteration 5003
# m 2.000000000000001, b 2.9999999999999947, cost 1.0255191767873153e-29 iteration 5004
# m 2.000000000000002, b 2.999999999999995, cost 1.0255191767873153e-29 iteration 5005
# m 2.000000000000001, b 2.9999999999999947, cost 1.0255191767873153e-29 iteration 5006
# m 2.000000000000002, b 2.999999999999995, cost 1.0255191767873153e-29 iteration 5007
# m 2.000000000000001, b 2.9999999999999947, cost 1.0255191767873153e-29 iteration 5008
# m 2.000000000000002, b 2.999999999999995, cost 1.0255191767873153e-29 iteration 5009
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

X = dataset[['Insured', 'Claims']]
y = dataset.Payment

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20,random_state = 2)

regressor = LinearRegression()
regressor.fit(X_train, y_train)
regressor_preds = regressor.predict(X_test)

print("Root Mean Squared error :", np.sqrt(mean_squared_error(y_test, regressor_preds)))
print("R^2 score = ", r2_score(y_test, regressor_preds))
# Out:
# Root Mean Squared error : 75180.8009409333
# R^2 score =  0.995114149224164

# %%
import numpy as np
import matplotlib.pyplot as plt
y_train_array = y_train.to_numpy()
y_reshape_train = y_train_array.reshape(1, -1)
plt.scatter(X_train.Insured, y_train, color='red')
plt.plot(X_train.Insured, regressor.predict(X_train), color='blue')
plt.title('Insured vs Payment (Training set)')
plt.xlabel('Insured')
plt.ylabel('Payment')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
y_test_array = y_test.to_numpy()
y_reshape_test = y_test_array.reshape(1, -1)
plt.scatter(X_test.Insured, y_test, color='red')
plt.plot(X_test.Insured, regressor.predict(X_test), color='blue')
plt.title('Insured vs Payment (Test set)')
plt.xlabel('Insured')
plt.ylabel('Payment')
plt.show()
